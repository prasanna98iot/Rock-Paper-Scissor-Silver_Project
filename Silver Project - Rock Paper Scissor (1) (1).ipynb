# %%
import random
def compchoice():
    chclst = ['rock','paper','scissor'] 
    c1 = random.randint(0,2)
    #if(c1>2):
     #   c1 = random.randint(0,1)
    #print(c1)
    #print(chclst[c1])
    return chclst[c1]
p1=""
point_p1 = 0
point_c1 = 0
tie_count = 0
while(p1!='exit'):
    print("(((((((((((((((((((     Welcome to Silver Game Show ROCK, PAPER & SCISSOR     )))))))))))))))))))")
    print("\nYour Choices are :\n1)Rock \n2)Paper \n3)Scissor \n To Exit: exit")
    p1 = str(input("\033[1m Enter your choice : "))
    p1 = p1.lower()
    c1 = compchoice()
    print(" Computers choice  :",c1,"\n")
    
    

    if(not((p1=='rock')or(p1=='paper')or(p1=='scissor')or(p1=='exit'))):
        print("Hello Brother / Sister")
        print("Check your spelling it should be \033[1m 'Rock or Paper or Scissor' \033[0m")     #\033[1m esc sequence to make text bold
                                                                                    #\033[0m reset bold text
    if(c1=='rock' and p1 == 'paper'):
        print('\033[94mYou Win\033[0m')
        point_p1+=1
    elif(c1=='rock' and p1 == 'scissor'):
        print('\033[94mComputer Wins\033[0m')
        point_c1+=1
    elif(c1=='paper' and p1 == 'rock'):
        print('\033[94mComputer Wins\033[0m')
        point_c1+=1
    elif(c1=='paper' and p1 == 'scissor'):
        print('\033[94mYou Win\033[0m')
        point_p1+=1
    elif(c1=='scissor' and p1 == 'rock'):
        print('\033[94mYou Win\033[0m')
        point_p1+=1
    elif(c1=='scissor' and p1 == 'paper'):
        print('\033[94mComputer Wins\033[0m')
        point_c1+=1
    elif(c1=='rock' and p1 == 'rock'):
        print('\033[94mIt\'s a tie\033[0m')
        tie_count+=1
    elif(c1=='paper' and p1 == 'paper'):
        print('\033[94mIt\'s a tie\033[0m')
        tie_count+=1
    elif(c1=='scissor' and p1 == 'scissor'):
        print('\033[94mIt\'s a tie\033[0m')
        tie_count+=1
    elif(p1=='exit'):
        print("\033[1mGame Exits\n\033[0m")
        if(point_p1>point_c1):
            print("\033[1m Finally player gets high score\033[0m")
        if(point_p1<point_c1):
            print("\033[1mFinally Computer gets high score\033[0m")
        if(point_p1==point_c1):
            print("\033[1mIt's a tie\033[0m")
        exit()
    print('\n------ScoreBoard------')
    print('Player Points:',point_p1)
    print('Computer Points',point_c1)
    print('Tie Count',tie_count)
    print('----------------------')
    print("\n")
# Out:
# (((((((((((((((((((     Welcome to Silver Game Show ROCK, PAPER & SCISSOR     )))))))))))))))))))
#
# Your Choices are :
# 1)Rock
# 2)Paper
# 3)Scissor
#  To Exit: exit
#  Enter your choice : rock
#  Computers choice  : rock
#
# It's a tie
#
# ------ScoreBoard------
# Player Points: 0
# Computer Points 0
# Tie Count 1
# ----------------------
#
#
# (((((((((((((((((((     Welcome to Silver Game Show ROCK, PAPER & SCISSOR     )))))))))))))))))))
#
# Your Choices are :
# 1)Rock
# 2)Paper
# 3)Scissor
#  To Exit: exit
#  Enter your choice : paper
#  Computers choice  : rock
#
# You Win
#
# ------ScoreBoard------
# Player Points: 1
# Computer Points 0
# Tie Count 1
# ----------------------
#
#
# (((((((((((((((((((     Welcome to Silver Game Show ROCK, PAPER & SCISSOR     )))))))))))))))))))
#
# Your Choices are :
# 1)Rock
# 2)Paper
# 3)Scissor
#  To Exit: exit
#  Enter your choice : scissor
#  Computers choice  : paper
#
# You Win
#
# ------ScoreBoard------
# Player Points: 2
# ...
